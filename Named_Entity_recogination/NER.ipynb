# %%
! pip install spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 4.1 MB/s  0:00:03 eta 0:00:01
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
from spacy import displacy
NER = spacy.load("en_core_web_sm")

# %%
text = 'Apple was founded by Steve Jobs in California in 1976.'
doc = NER(text)

# %%
for word in NER(text).ents:
    print(word.text,word.label_)
# Out:
# Apple ORG
# Steve Jobs PERSON
# California GPE
# 1976 DATE

# %%
print(spacy.explain("ORG"))
print(spacy.explain("GPE"))
print(spacy.explain("DATE"))
print(spacy.explain("PERSON"))
# Out:
# Companies, agencies, institutions, etc.
# Countries, cities, states
# Absolute or relative dates or periods
# People, including fictional

# %%
displacy.render(doc,style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  was founded by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Steve Jobs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     California
# ...

# %%
doc2 = NER("The Indian Space Research Organisation or is the national space agency of India, headquartered in Bengaluru. It operates under Department of Space which is directly overseen by the Prime Minister of India while Chairman of ISRO acts as executive of DOS as well.")

# %%
displacy.render(doc2,style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Indian Space Research Organisation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  or is the national space agency of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , headquartered in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bengaluru
# ...

# %% [markdown]
# ## another example with more Name entity

# %%
doc3 = NER("""Elon Musk founded SpaceX in 2002 in the United States. 
The company later launched Falcon 9 rockets from Florida and became one of the most important private space companies in the world. 
In 2020, NASA worked with SpaceX to send astronauts from the Kennedy Space Center to the International Space Station. 
Meanwhile, Apple CEO Tim Cook announced the new iPhone in California on September 12, 2023. 
The company reported revenue of $383 billion that year and sold millions of iPhones across the United States, India, China, and Europe. 
Microsoft, headquartered in Redmond, Washington, invested billions of dollars in artificial intelligence and expanded its partnership with OpenAI. 
In London, Google organized a technology conference where Sundar Pichai discussed AI, Google Gemini, and the future of search. 
The event attracted more than 10,000 developers from countries including India, Germany, France, Japan, and Canada.""")

# %%
for doc in doc3.ents:
    print(doc.text, doc.label_)
# Out:
# Elon Musk PERSON
# 2002 DATE
# the United States GPE
# Falcon ORG
# Florida GPE
# 2020 DATE
# NASA ORG
# the Kennedy Space Center FAC
# the International Space Station ORG
# Apple ORG
# Tim Cook PERSON
# California GPE
# September 12, 2023 DATE
# $383 billion MONEY
# that year DATE
# millions CARDINAL
# iPhones ORG
# the United States GPE
# India GPE
# China GPE
# Europe LOC
# Microsoft ORG
# Redmond GPE
# Washington GPE
# billions of dollars MONEY
# OpenAI PERSON
# London GPE
# Google ORG
# Sundar Pichai ORG
# AI GPE
# Google Gemini ORG
# more than 10,000 CARDINAL
# India GPE
# Germany GPE
# France GPE
# Japan GPE
# Canada GPE

# %%
displacy.render(doc3,style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  founded SpaceX in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2002
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
# ...

# %%
spacy.explain("PRODUCT")
# Out:
# 'Objects, vehicles, foods, etc. (not services)'

# %%
spacy.explain("MONEY")
# Out:
# 'Monetary values, including unit'

# %%
spacy.explain("FAC")
# Out:
# 'Buildings, airports, highways, bridges, etc.'

# %%
spacy.explain("LOC")
# Out:
# 'Non-GPE locations, mountain ranges, bodies of water'

# %%
spacy.explain("CARDINAL")
# Out:
# 'Numerals that do not fall under another type'

# %%
! pip install bs4

# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
URL="https://sih.gov.in/sih2026PS"

# %%
html_text = requests.get(URL).text
soup = BeautifulSoup(html_text,"lxml")
body = soup.body.text

# %%
body= body.replace('n', ' ')
body= body.replace('t', ' ')
body= body.replace('r', ' ')
body= body.replace('xa0', ' ')
body = re.sub(r'\s+', ' ', body).strip()

# %%
# Out:
# ''

# %%
from langchain_community.document_loaders import WebBaseLoader
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
loader = WebBaseLoader(URL)

# %%
docs =loader.load() 
print(docs)

# %%
text = docs[0].page_content

text = re.sub(r'\s+', ' ', text).strip()
text

# %%
doc4=NER(text)

# %%
displacy.render(doc4,style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Smart
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Hackathon MIC Alumni SIH Login Home(current) About SIH SIH Process Flow SIH Themes Implementation Team SIH Past Editions SIH 2017 SIH
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2018
# ...
